# %% [markdown]
# # DSA5104 Project Data Cleaning

# %%
filename_calendar = 'calendar.csv'
filename_listings_sum = 'listings_summary.csv'
filename_listings = 'listings.csv'
filename_reviews_sum = 'reviews_summary.csv'
filename_reviews = 'reviews.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
calendar = pd.read_csv(filename_calendar, dtype = str)
listings_summary = pd.read_csv(filename_listings_sum, dtype = str)
listings = pd.read_csv(filename_listings, dtype = str)
reviews_summary = pd.read_csv(filename_reviews_sum, dtype = str)
reviews = pd.read_csv(filename_reviews, dtype = str)

# %% [markdown]
# # Data cleaning process

# %% [markdown]
# ## calendar

# %%
calendar.head()
# Out:
#            listing_id        date available    price adjusted_price  \
# 0  645048906856594097  2022-06-20         t  $890.00        $890.00
# 1  645048906856594097  2022-06-21         t  $890.00        $890.00
# 2  645048906856594097  2022-06-22         t  $890.00        $890.00
# 3  645048906856594097  2022-06-23         t  $890.00        $890.00
# 4  645048906856594097  2022-06-24         t  $890.00        $890.00
#
#   minimum_nights maximum_nights
# 0              1            365
# 1              1            365
# 2              1            365
# 3              1            365
# 4              1            365

# %%
calendar.shape
# Out:
# (6231645, 7)

# %%
calendar.isnull().sum()[calendar.isnull().sum() > 0]
# Out:
# minimum_nights    2
# maximum_nights    2
# dtype: int64

# %% [markdown]
# - for "minimum_nights" and "maximum_nights", we simply drop the null records since they are very few

# %%
calendar.drop(index = calendar[calendar.minimum_nights.isnull() == True].index, axis = 0, inplace = True)

# %%
calendar.isnull().sum()[calendar.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# - for 'price' and 'adjusted_price', we change it to float!

# %%
calendar['price'] = calendar['price'].apply(lambda x: x.replace('$', ''))
calendar['adjusted_price'] = calendar['adjusted_price'].apply(lambda x: x.replace('$', ''))

# %%
calendar.head()
# Out:
#            listing_id        date available   price adjusted_price  \
# 0  645048906856594097  2022-06-20         t  890.00         890.00
# 1  645048906856594097  2022-06-21         t  890.00         890.00
# 2  645048906856594097  2022-06-22         t  890.00         890.00
# 3  645048906856594097  2022-06-23         t  890.00         890.00
# 4  645048906856594097  2022-06-24         t  890.00         890.00
#
#   minimum_nights maximum_nights
# 0              1            365
# 1              1            365
# 2              1            365
# 3              1            365
# 4              1            365

# %% [markdown]
# ## listings

# %% [markdown]
# ### Firstly, get some insights around data

# %%
listings[['neighbourhood_cleansed', 'neighbourhood_group_cleansed']].head()
# Out:
#   neighbourhood_cleansed neighbourhood_group_cleansed
# 0               Bang Sue                          NaN
# 1               Bang Sue                          NaN
# 2                 Lak Si                          NaN
# 3                 Lak Si                          NaN
# 4          Khlong Sam Wa                          NaN

# %%
listings.head(1)['amenities']
# Out:
# 0    ["Kitchen", "Air conditioning", "Free parking ...
# Name: amenities, dtype: object

# %%
listings[['property_type', 'room_type']].head()
# Out:
#                  property_type        room_type
# 0                 Entire condo  Entire home/apt
# 1  Private room in rental unit     Private room
# 2        Private room in condo     Private room
# 3        Private room in condo     Private room
# 4         Private room in home     Private room

# %%
listings[['bathrooms','bathrooms_text']].head()
# Out:
#   bathrooms  bathrooms_text
# 0       NaN          1 bath
# 1       NaN          1 bath
# 2       NaN          1 bath
# 3       NaN  1 private bath
# 4       NaN  2 shared baths

# %%
listings[['bedrooms', 'beds']].head()
# Out:
#   bedrooms beds
# 0        1    1
# 1        1    1
# 2        1    1
# 3        1    1
# 4        1    1

# %% [markdown]
#     - future x days, the availability situation

# %%
listings[['has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365']].head(10)
# Out:
#   has_availability availability_30 availability_60 availability_90  \
# 0                t              30              60              90
# 1                t              27              57              87
# 2                t              28              58              88
# 3                t              30              60              90
# 4                t              27              57              87
# 5                t              24              54              84
# 6                t              27              57              87
# 7                t              23              53              83
# 8                t              30              60              90
# 9                t              30              60              90
#
#   availability_365
# 0              365
# 1              362
# 2               89
# 3              181
# 4               88
# 5              359
# 6              362
# 7              358
# 8              365
# 9              365

# %% [markdown]
#     - ltm: last 12 months
#     - l30d: last 30 days

# %%
listings[['number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review']].head(10)
# Out:
#   number_of_reviews number_of_reviews_ltm number_of_reviews_l30d first_review  \
# 0                 0                     0                      0          NaN
# 1                 0                     0                      0          NaN
# 2                 6                     0                      0   2019-11-15
# 3                 3                     0                      0   2019-06-01
# 4                 0                     0                      0          NaN
# 5                 0                     0                      0          NaN
# 6                65                     0                      0   2012-04-07
# 7                 0                     0                      0          NaN
# 8                 0                     0                      0          NaN
# 9                 2                     1                      0   2016-07-13
#
#   last_review
# 0         NaN
# 1         NaN
# 2  2020-03-05
# 3  2019-12-07
# 4         NaN
# 5         NaN
# 6  2020-01-06
# 7         NaN
# 8         NaN
# 9  2022-04-01

# %%
listings[['instant_bookable', 'has_availability']].head()
# Out:
#   instant_bookable has_availability
# 0                t                t
# 1                f                t
# 2                t                t
# 3                t                t
# 4                t                t

# %%
listings.head()
# Out:
#                    id                                      listing_url  \
# 0  645048906856594097  https://www.airbnb.com/rooms/645048906856594097
# 1            15636062            https://www.airbnb.com/rooms/15636062
# 2            39544047            https://www.airbnb.com/rooms/39544047
# 3            34002624            https://www.airbnb.com/rooms/34002624
# 4            22678899            https://www.airbnb.com/rooms/22678899
#
#         scrape_id last_scraped  \
# 0  20220620202126   2022-06-20
# 1  20220620202126   2022-06-20
# 2  20220620202126   2022-06-20
# 3  20220620202126   2022-06-20
# 4  20220620202126   2022-06-20
#
#                                              name  \
# 0   Furnished 1 bedroom condo with beautiful view
# 1                        Akesin place ngamwongwan
# 2  IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                       Popular Condo Near IMPACT
# 4                                       บ้านเบนซ์
#
#                                          description  \
# 0  🏢Condo For rent: Lumpini Ville Nakhon In-River...
# 1  ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...
# 2                                                NaN
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4  เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...
#
#                                neighborhood_overview  \
# 0                            Its in Lumpini building
# 1                                                NaN
# 2  IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4                                                NaN
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    4663219
# 1  https://a0.muscache.com/pictures/f68098b9-3ff2...  100840975
# 2  https://a0.muscache.com/pictures/cc410e7d-922f...  303573998
# 3  https://a0.muscache.com/pictures/e4811699-0153...  256747704
# 4  https://a0.muscache.com/pictures/02e4ae53-dbe6...  167136634
#
#                                       host_url  ...  \
# 0    https://www.airbnb.com/users/show/4663219  ...
# 1  https://www.airbnb.com/users/show/100840975  ...
# 2  https://www.airbnb.com/users/show/303573998  ...
# 3  https://www.airbnb.com/users/show/256747704  ...
# 4  https://www.airbnb.com/users/show/167136634  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                         NaN                    NaN                 NaN
# 2                         5.0                   4.67                4.67
# 3                         4.0                    4.5                 4.0
# 4                         NaN                    NaN                 NaN
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                t                              1
# 1     NaN                f                              1
# 2     NaN                t                              2
# 3     NaN                t                              1
# 4     NaN                t                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            2
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0               NaN
# 2                                           0              0.19
# 3                                           0              0.08
# 4                                           0               NaN
#
# [5 rows x 74 columns]

# %%
listings.shape
# Out:
# (17074, 74)

# %%
listings.isnull().sum()[listings.isnull().sum() > 0]
# Out:
# name                                9
# description                       905
# neighborhood_overview            7615
# host_name                           2
# host_since                          2
# host_location                      44
# host_about                       7241
# host_response_time               5629
# host_response_rate               5629
# host_acceptance_rate             6779
# host_is_superhost                   2
# host_thumbnail_url                  2
# host_picture_url                    2
# host_neighbourhood               7262
# host_listings_count                 2
# host_total_listings_count           2
# host_has_profile_pic                2
# host_identity_verified              2
# neighbourhood                    7615
# neighbourhood_group_cleansed    17074
# bathrooms                       17074
# bathrooms_text                    137
# bedrooms                         1703
# beds                              517
# minimum_minimum_nights              1
# maximum_minimum_nights              1
# minimum_maximum_nights              1
# maximum_maximum_nights              1
# minimum_nights_avg_ntm              1
# maximum_nights_avg_ntm              1
# calendar_updated                17074
# first_review                     7062
# last_review                      7062
# review_scores_rating             7062
# review_scores_accuracy           7288
# review_scores_cleanliness        7288
# review_scores_checkin            7294
# review_scores_communication      7289
# review_scores_location           7295
# review_scores_value              7296
# license                         17074
# reviews_per_month                7062
# dtype: int64

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ### Check those attributes which are all NaN

# %%
delete_list = []
for attr in listings.isnull().sum()[listings.isnull().sum() == listings.shape[0]].index:
    delete_list.append(attr)

# %%
delete_list
# Out:
# ['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated', 'license']

# %%
listings.drop(delete_list, axis = 1, inplace = True)

# %%
listings.head()
# Out:
#                    id                                      listing_url  \
# 0  645048906856594097  https://www.airbnb.com/rooms/645048906856594097
# 1            15636062            https://www.airbnb.com/rooms/15636062
# 2            39544047            https://www.airbnb.com/rooms/39544047
# 3            34002624            https://www.airbnb.com/rooms/34002624
# 4            22678899            https://www.airbnb.com/rooms/22678899
#
#         scrape_id last_scraped  \
# 0  20220620202126   2022-06-20
# 1  20220620202126   2022-06-20
# 2  20220620202126   2022-06-20
# 3  20220620202126   2022-06-20
# 4  20220620202126   2022-06-20
#
#                                              name  \
# 0   Furnished 1 bedroom condo with beautiful view
# 1                        Akesin place ngamwongwan
# 2  IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                       Popular Condo Near IMPACT
# 4                                       บ้านเบนซ์
#
#                                          description  \
# 0  🏢Condo For rent: Lumpini Ville Nakhon In-River...
# 1  ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...
# 2                                                NaN
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4  เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...
#
#                                neighborhood_overview  \
# 0                            Its in Lumpini building
# 1                                                NaN
# 2  IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4                                                NaN
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    4663219
# 1  https://a0.muscache.com/pictures/f68098b9-3ff2...  100840975
# 2  https://a0.muscache.com/pictures/cc410e7d-922f...  303573998
# 3  https://a0.muscache.com/pictures/e4811699-0153...  256747704
# 4  https://a0.muscache.com/pictures/02e4ae53-dbe6...  167136634
#
#                                       host_url  ... review_scores_checkin  \
# 0    https://www.airbnb.com/users/show/4663219  ...                   NaN
# 1  https://www.airbnb.com/users/show/100840975  ...                   NaN
# 2  https://www.airbnb.com/users/show/303573998  ...                   5.0
# 3  https://www.airbnb.com/users/show/256747704  ...                   5.0
# 4  https://www.airbnb.com/users/show/167136634  ...                   NaN
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                         NaN                    NaN                 NaN
# 2                         5.0                   4.67                4.67
# 3                         4.0                    4.5                 4.0
# 4                         NaN                    NaN                 NaN
#
#   instant_bookable calculated_host_listings_count  \
# 0                t                              1
# 1                f                              1
# 2                t                              2
# 3                t                              1
# 4                t                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            2
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0               NaN
# 2                                           0              0.19
# 3                                           0              0.08
# 4                                           0               NaN
#
# [5 rows x 70 columns]

# %% [markdown]
# ## 1. Check those attributes which have few NaNs (in details)
# - for those attributes, since the quantity is very small, we can simply drop them!

# %%
listings.isnull().sum()[(listings.isnull().sum() < 50) & (listings.isnull().sum() > 0)]
# Out:
# name                          9
# host_name                     2
# host_since                    2
# host_location                44
# host_is_superhost             2
# host_thumbnail_url            2
# host_picture_url              2
# host_listings_count           2
# host_total_listings_count     2
# host_has_profile_pic          2
# host_identity_verified        2
# minimum_minimum_nights        1
# maximum_minimum_nights        1
# minimum_maximum_nights        1
# maximum_maximum_nights        1
# minimum_nights_avg_ntm        1
# maximum_nights_avg_ntm        1
# dtype: int64

# %% [markdown]
# - name, for this case, it is likely to be the case that, they only lose their title name for some reason
#     - I think it is not a crucial problem, so I choose to still save these records and set null value for 'name'
#     - for the simplicity, we kick them out

# %%
listings[listings.name.isnull() == True]
# Out:
#              id                            listing_url       scrape_id  \
# 441     4245018   https://www.airbnb.com/rooms/4245018  20220620202126
# 527     4720818   https://www.airbnb.com/rooms/4720818  20220620202126
# 637     4549768   https://www.airbnb.com/rooms/4549768  20220620202126
# 1081    6148415   https://www.airbnb.com/rooms/6148415  20220620202126
# 1195    8055144   https://www.airbnb.com/rooms/8055144  20220620202126
# 1623   10000742  https://www.airbnb.com/rooms/10000742  20220620202126
# 1870   10710165  https://www.airbnb.com/rooms/10710165  20220620202126
# 2307   13142743  https://www.airbnb.com/rooms/13142743  20220620202126
# 16438   5709288   https://www.airbnb.com/rooms/5709288  20220620202126
#
#       last_scraped name                                        description  \
# 441     2022-06-20  NaN  <b>The space</b><br />The old shop house was b...
# 527     2022-06-21  NaN  Room for rent near MRT Huay Kwang station.<br ...
# 637     2022-06-21  NaN                                                NaN
# 1081    2022-06-21  NaN  <b>The space</b><br />Feature / description<br...
# 1195    2022-06-21  NaN  Luxury Condominium in CBD area of Bangkok, Suk...
# 1623    2022-06-21  NaN  Diamond Bangkok<br />Near BTS Ratchathewi Stat...
# 1870    2022-06-21  NaN  -Fully furnished with modern closet, dressing ...
# 2307    2022-06-21  NaN  Errday Guest House for rent daily, monthly, co...
# 16438   2022-06-20  NaN  Private room for 2 persons  with city view fro...
#
#                                    neighborhood_overview  \
# 441                                                  NaN
# 527                                                  NaN
# 637                                                  NaN
# 1081   Location<br />Absolute convenience / Transport...
# 1195                                                 NaN
# 1623   Diamond Bangkok<br />Near BTS Ratchathewi Stat...
# 1870                                                 NaN
# 2307                                                 NaN
# 16438          It has many favourite places around here.
#
#                                              picture_url   host_id  \
# 441    https://a0.muscache.com/pictures/53314583/1591...  22030043
# 527    https://a0.muscache.com/pictures/59268815/48c0...  24386225
# 637    https://a0.muscache.com/pictures/57555128/251b...  18852579
# 1081   https://a0.muscache.com/pictures/76635501/2816...  31895202
# 1195   https://a0.muscache.com/pictures/102664030/c25...  42521288
# 1623   https://a0.muscache.com/pictures/e69fd5f9-b619...  51374914
# 1870   https://a0.muscache.com/pictures/fee3ff6b-a268...  55347997
# 2307   https://a0.muscache.com/pictures/1887b079-baae...  73275200
# 16438  https://a0.muscache.com/pictures/71049021/b057...  29602043
#
#                                          host_url  ... review_scores_checkin  \
# 441    https://www.airbnb.com/users/show/22030043  ...                   NaN
# 527    https://www.airbnb.com/users/show/24386225  ...                   NaN
# 637    https://www.airbnb.com/users/show/18852579  ...                   NaN
# 1081   https://www.airbnb.com/users/show/31895202  ...                   NaN
# 1195   https://www.airbnb.com/users/show/42521288  ...                   NaN
# 1623   https://www.airbnb.com/users/show/51374914  ...                   3.0
# 1870   https://www.airbnb.com/users/show/55347997  ...                   NaN
# 2307   https://www.airbnb.com/users/show/73275200  ...                   5.0
# 16438  https://www.airbnb.com/users/show/29602043  ...                   NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 441                           NaN                    NaN                 NaN
# 527                           NaN                    NaN                 NaN
# 637                           NaN                    NaN                 NaN
# 1081                          NaN                    NaN                 NaN
# 1195                          NaN                    NaN                 NaN
# 1623                          3.0                   4.17                3.83
# 1870                          NaN                    NaN                 NaN
# 2307                          5.0                    3.5                 4.5
# 16438                         NaN                    NaN                 NaN
#
#       instant_bookable calculated_host_listings_count  \
# 441                  f                              1
# 527                  f                              1
# 637                  f                              1
# 1081                 f                              1
# 1195                 t                              1
# 1623                 t                              1
# 1870                 t                              1
# 2307                 f                              3
# 16438                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 441                                             0
# 527                                             0
# 637                                             0
# 1081                                            1
# 1195                                            0
# 1623                                            0
# 1870                                            0
# 2307                                            0
# 16438                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 441                                              1
# 527                                              1
# 637                                              1
# 1081                                             0
# 1195                                             1
# 1623                                             1
# 1870                                             1
# 2307                                             3
# 16438                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 441                                             0               NaN
# 527                                             0               NaN
# 637                                             0               NaN
# 1081                                            0               NaN
# 1195                                            0               NaN
# 1623                                            0              0.08
# 1870                                            0               NaN
# 2307                                            0              0.03
# 16438                                           0               NaN
#
# [9 rows x 70 columns]

# %%
listings.drop(index = listings[listings.name.isnull() == True].index, axis = 0, inplace =True)

# %% [markdown]
# - host_name, it can be observed that, all host-related information is loss for this case
#     - since there are not too many records, we choose to kick out them for the well-structured of DB

# %%
listings[listings.host_name.isnull() == True][['id', 'host_is_superhost', 'host_picture_url', 'host_name', 'host_location']]
# Out:
#              id host_is_superhost host_picture_url host_name host_location
# 7860   31809614               NaN              NaN       NaN           NaN
# 12775  42181585               NaN              NaN       NaN           NaN

# %%
listings.drop(index = listings[listings.host_name.isnull() == True][['id', 'host_is_superhost', 'host_picture_url', 'host_name', 'host_location']].index, axis = 0, inplace = True)

# %% [markdown]
# - host_location, drop it!

# %%
listings[listings.host_location.isnull() == True]
# Out:
#              id                            listing_url       scrape_id  \
# 764     5727012   https://www.airbnb.com/rooms/5727012  20220620202126
# 1379    8855331   https://www.airbnb.com/rooms/8855331  20220620202126
# 1682   10324572  https://www.airbnb.com/rooms/10324572  20220620202126
# 1799   11288172  https://www.airbnb.com/rooms/11288172  20220620202126
# 2224   13451554  https://www.airbnb.com/rooms/13451554  20220620202126
# 2475   13982700  https://www.airbnb.com/rooms/13982700  20220620202126
# 2590   14149434  https://www.airbnb.com/rooms/14149434  20220620202126
# 2592   14150329  https://www.airbnb.com/rooms/14150329  20220620202126
# 2632   14903399  https://www.airbnb.com/rooms/14903399  20220620202126
# 2672   14941205  https://www.airbnb.com/rooms/14941205  20220620202126
# 2745   15025651  https://www.airbnb.com/rooms/15025651  20220620202126
# 2926   15604282  https://www.airbnb.com/rooms/15604282  20220620202126
# 2937   15627431  https://www.airbnb.com/rooms/15627431  20220620202126
# 3264   16862265  https://www.airbnb.com/rooms/16862265  20220620202126
# 3635   17813806  https://www.airbnb.com/rooms/17813806  20220620202126
# 3642   17953432  https://www.airbnb.com/rooms/17953432  20220620202126
# 3748   18014713  https://www.airbnb.com/rooms/18014713  20220620202126
# 3768   18029869  https://www.airbnb.com/rooms/18029869  20220620202126
# 4363   20976893  https://www.airbnb.com/rooms/20976893  20220620202126
# 4383   20999170  https://www.airbnb.com/rooms/20999170  20220620202126
# 4643   21244581  https://www.airbnb.com/rooms/21244581  20220620202126
# 5918   25428278  https://www.airbnb.com/rooms/25428278  20220620202126
# 6890   29224804  https://www.airbnb.com/rooms/29224804  20220620202126
# 6903   29245979  https://www.airbnb.com/rooms/29245979  20220620202126
# 6980   29325880  https://www.airbnb.com/rooms/29325880  20220620202126
# 7849   31344724  https://www.airbnb.com/rooms/31344724  20220620202126
# 7946   31399742  https://www.airbnb.com/rooms/31399742  20220620202126
# 8549   33358939  https://www.airbnb.com/rooms/33358939  20220620202126
# 8550   33359405  https://www.airbnb.com/rooms/33359405  20220620202126
# 9417   35084801  https://www.airbnb.com/rooms/35084801  20220620202126
# 10502  38123673  https://www.airbnb.com/rooms/38123673  20220620202126
# 12128   https://www.airbnb.com/users/show/42813683  ...                   NaN
# 13186   https://www.airbnb.com/users/show/68176290  ...                   NaN
# 13232  https://www.airbnb.com/users/show/103089505  ...                   NaN
# 13328  https://www.airbnb.com/users/show/128808156  ...                   NaN
# 13634   https://www.airbnb.com/users/show/51043669  ...                   NaN
# 13755   https://www.airbnb.com/users/show/55729958  ...                   NaN
# 16642   https://www.airbnb.com/users/show/81112485  ...                   5.0
# 16835  https://www.airbnb.com/users/show/110807325  ...                   NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 764                           5.0                   4.57                4.57
# 1379                          NaN                    NaN                 NaN
# 1682                          NaN                    NaN                 NaN
# 1799                          NaN                    NaN                 NaN
# 2224                          5.0                    5.0                 5.0
# 2475                          NaN                    NaN                 NaN
# 2590                          NaN                    NaN                 NaN
# 2592                          NaN                    NaN                 NaN
# 2632                          NaN                    NaN                 NaN
# 2672                          NaN                    NaN                 NaN
# 2745                          1.0                    1.0                 1.0
# 2926                          4.5                   4.83                4.67
# 2937                          NaN                    NaN                 NaN
# 3264                          NaN                    NaN                 NaN
# 3635                          NaN                    NaN                 NaN
# 3642                          NaN                    NaN                 NaN
# 3748                          NaN                    NaN                 NaN
# 3768                          NaN                    NaN                 NaN
# 4363                          NaN                    NaN                 NaN
# 4383                          NaN                    NaN                 NaN
# 4643                          NaN                    NaN                 NaN
# 5918                          4.0                    4.0                 5.0
# 6890                          NaN                    NaN                 NaN
# 6903                          2.5                    3.0                 2.0
# 6980                          NaN                    NaN                 NaN
# 7849                          NaN                    NaN                 NaN
# 7946                          1.0                    1.0                 1.0
# 8549                          4.9                   4.68                4.73
# 8550                         4.94                   4.41                4.41
# 9417                          NaN                    NaN                 NaN
# 10502                         NaN                    NaN                 NaN
# 11117                         NaN                    NaN                 NaN
# 11195                         NaN                    NaN                 NaN
# 11844                         NaN                    NaN                 NaN
# 12128                         NaN                    NaN                 NaN
# 13186                         NaN                    NaN                 NaN
# 13232                         NaN                    NaN                 NaN
# 13328                         NaN                    NaN                 NaN
# 13634                         NaN                    NaN                 NaN
# 13755                         NaN                    NaN                 NaN
# 16642                         5.0                    4.0                 5.0
# 16835                         NaN                    NaN                 NaN
#
#       instant_bookable calculated_host_listings_count  \
# 764                  f                              1
# 1379                 f                              1
# 1682                 f                              1
# 1799                 f                              1
# 2224                 f                              1
# 2475                 f                              1
# 2590                 t                              2
# 2592                 f                              2
# 2632                 t                              1
# 2672                 t                              1
# 2745                 t                              1
# 2926                 f                              1
# 2937                 f                              1
# 3264                 t                              1
# 3635                 t                              1
# 3642                 f                              1
# 3748                 f                              1
# 3768                 t                              1
# 4363                 t                              1
# 4383                 t                              1
# 4643                 t                              1
# 5918                 t                              1
# 6890                 f                              1
# 6903                 t                              2
# 6980                 f                              1
# 7849                 t                              1
# 7946                 t                              2
# 8549                 t                              2
# 8550                 t                              2
# 9417                 t                              1
# 10502                t                              1
# 11117                t                              2
# 11195                t                              2
# 11844                t                              1
# 12128                t                              1
# 13186                t                              1
# 13232                t                              1
# 13328                t                              1
# 13634                f                              1
# 13755                t                              1
# 16642                t                              1
# 16835                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 764                                             1
# 1379                                            0
# 1682                                            1
# 1799                                            0
# 2224                                            1
# 2475                                            1
# 2590                                            2
# 2592                                            2
# 2632                                            0
# 2672                                            0
# 2745                                            0
# 2926                                            1
# 2937                                            0
# 3264                                            0
# 3635                                            1
# 3642                                            0
# 3748                                            1
# 3768                                            0
# 4363                                            1
# 4383                                            0
# 4643                                            0
# 5918                                            0
# 6890                                            1
# 6903                                            0
# 6980                                            1
# 7849                                            1
# 7946                                            0
# 8549                                            2
# 8550                                            2
# 9417                                            0
# 10502                                           1
# 11117                                           0
# 11195                                           0
# 11844                                           1
# 12128                                           0
# 13186                                           0
# 13232                                           1
# 13328                                           1
# 13634                                           1
# 13755                                           0
# 16642                                           1
# 16835                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 764                                              0
# 1379                                             1
# 1682                                             0
# 1799                                             1
# 2224                                             0
# 2475                                             0
# 2590                                             0
# 2592                                             0
# 2632                                             1
# 2672                                             1
# 2745                                             1
# 2926                                             0
# 2937                                             1
# 3264                                             1
# 3635                                             0
# 3642                                             1
# 3748                                             0
# 3768                                             1
# 4363                                             0
# 4383                                             1
# 4643                                             0
# 5918                                             1
# 6890                                             0
# 6903                                             2
# 6980                                             0
# 7849                                             0
# 7946                                             2
# 8549                                             0
# 8550                                             0
# 9417                                             1
# 10502                                            0
# 11117                                            0
# 11195                                            0
# 11844                                            0
# 12128                                            1
# 13186                                            1
# 13232                                            0
# 13328                                            0
# 13634                                            0
# 13755                                            1
# 16642                                            0
# 16835                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 764                                             0              0.08
# 1379                                            0               NaN
# 1682                                            0               NaN
# 1799                                            0               NaN
# 2224                                            0              0.05
# 2475                                            0               NaN
# 2590                                            0               NaN
# 2592                                            0               NaN
# 2632                                            0               NaN
# 2672                                            0               NaN
# 2745                                            0              0.02
# 2926                                            0              0.12
# 2937                                            0               NaN
# 3264                                            0               NaN
# 3635                                            0              0.02
# 3642                                            0               NaN
# 3748                                            0               NaN
# 3768                                            0               NaN
# 4363                                            0               NaN
# 4383                                            0               NaN
# 4643                                            1               NaN
# 5918                                            0              0.02
# 6890                                            0               NaN
# 6903                                            0              0.05
# 6980                                            0               NaN
# 7849                                            0              0.03
# 7946                                            0              0.03
# 8549                                            0              1.05
# 8550                                            0              0.46
# 9417                                            0               NaN
# 10502                                           0              0.03
# 11117                                           2               NaN
# 11195                                           2               NaN
# 11844                                           0               NaN
# 12128                                           0               NaN
# 13186                                           0               NaN
# 13232                                           0               NaN
# 13328                                           0               NaN
# 13634                                           0               NaN
# 13755                                           0               NaN
# 16642                                           0              0.06
# 16835                                           0               NaN
#
# [42 rows x 70 columns]

# %%
listings.drop(index = listings[listings.host_location.isnull() == True].index, axis = 0, inplace = True)

# %% [markdown]
# - minimum_minimum_nights, drop it

# %%
listings[listings.minimum_minimum_nights.isnull() == True]
# Out:
#              id                            listing_url       scrape_id  \
# 13729  44563108  https://www.airbnb.com/rooms/44563108  20220620202126
#
#       last_scraped                           name description  \
# 13729   2022-06-21  Somerset Maison Asoke Bangkok         NaN
#
#       neighborhood_overview  \
# 13729                   NaN
#
#                                              picture_url    host_id  \
# 13729  https://a0.muscache.com/pictures/miso/Hosting-...  360620448
#
#                                           host_url  ... review_scores_checkin  \
# 13729  https://www.airbnb.com/users/show/360620448  ...                   NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 13729                         NaN                    NaN                 NaN
#
#       instant_bookable calculated_host_listings_count  \
# 13729                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 13729                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 13729                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 13729                                           0               NaN
#
# [1 rows x 70 columns]

# %%
listings.drop(index = listings[listings.minimum_minimum_nights.isnull() == True].index, axis = 0, inplace =True)

# %% [markdown]
# ### check the table after dealing with the FEW NULL value

# %%
listings.isnull().sum()[(listings.isnull().sum() < 50) & (listings.isnull().sum() > 0)]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 2. Check those features which have many NULL value

# %%
listings.isnull().sum()[listings.isnull().sum() != 0]
# Out:
# description                     899
# neighborhood_overview          7581
# host_about                     7192
# host_response_time             5585
# host_response_rate             5585
# host_acceptance_rate           6732
# host_neighbourhood             7222
# neighbourhood                  7581
# bathrooms_text                  136
# bedrooms                       1699
# beds                            515
# first_review                   7023
# last_review                    7023
# review_scores_rating           7023
# review_scores_accuracy         7246
# review_scores_cleanliness      7246
# review_scores_checkin          7252
# review_scores_communication    7247
# review_scores_location         7253
# review_scores_value            7254
# reviews_per_month              7023
# dtype: int64

# %% [markdown]
# - description (null imputation)

# %%
listings.loc[3, 'description']
# Out:
# 'คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค้าอิมแพค เมืองทองธานี ถ.แจ้งวัฒนะ มีสิ่งอำนวยความสะดวกครบครัน<br /><br />พร้อมดูแล ท่าน สนใจห้องพัก อื่นๆ หรืออยากเปลี่ยนห้องพัก หรือต้องการสิ่งใด โปรดติดต่อ ได้ตลอดเวลา<br /><br />Popular Condo สถานที่ตั้งของที่พักใกล้ - IMPACT , Challenger และ Hall 1-8 เดินทางสะดวกเพียงใช้เวลาเดินเพียง 5-10 นาที -  มหาวิทยาลัยสุโขทัยธรรมาธิราชเพียง 1.8 กิโลเมตร - สนามบินดอนเมืองเพียง 5 กิโลเมตร - เซ็นทรัลพลาซ่าแจ้งวัฒนะ เดินทางโดยรถยนต์ 10 นาที<br /><br /><b>The space</b><br />Popular Condo  สถานที่ตั้งของที่พักใกล้ - IMPACT , Challenger และ Hall 1-8 เดินทางสะดวกเพียงใช้เวลาเดินเพียง 5-10 นาที - ใกล้ Out let และห้างคอสโมสะดวกสบายในการหาของกิน - มหาวิทยาลัยสุโขทัยธรรมาธิราชเพียง 1.8 กิโลเมตร - สนามบินดอนเมืองเพียง 5 กิโลเมตร - เซ็นทรัลพลาซ่าแจ้งวัฒนะ เดินทางโดยรถยนต์ 10 นาที ที่พักมี Free Wifi ทีวีจอแบน ตู้เย็น ไมโครเวฟ เครื่องทำน้าอุ่น ฟรีที่จอดรถบริเวรใกล้เคียง<br /><br /><b>Guest access</b><br />สามารถใช้ได้ทั้งหมด<br /><br /><b>Other things to note</b>'

# %%
listings.loc[0, 'description']
# Out:
# '🏢Condo For rent: Lumpini Ville Nakhon In-Riverview Condo 🏢<br /><br /> 🚘 Only 1.3 km. from the Purple Line  🚄 Yaek Tiwanon Station, near Lotus and Makro, Nakhon In and BigC Tiwanon<br /><br /><b>The space</b><br />32 sqm<br /><br /><b>Guest access</b><br />You will get the entire condo access alont with elevator card'

# %% [markdown]
# - neighborhood_overview (null imputation)

# %%
listings.loc[0, 'neighborhood_overview']
# Out:
# 'Its in Lumpini building'

# %%
listings.loc[2, 'neighborhood_overview']
# Out:
# 'IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Challenger        650 m<br />IMPACT Arena.                 400 m<br />IMPACT Forum ,hall4.     850 m<br />IMPACT Hall5.                    450 m<br />Cosmo Bazaar.                  350 m<br />เซ็นทรัลพล่าซ่า แจ้งวัฒนะ.  2.6 km.<br />SCG Stadium.                      1.1 km.<br />Thunder Dome.                  1.0 km.'

# %%
listings.loc[1, 'neighborhood_overview']
# Out:
# nan

# %% [markdown]
# - host_about, sentences to introduce the host (null imputation)

# %%
listings.loc[8, 'host_about']
# Out:
# 'Welcome to Familyroom Apartment.\r\n\r\nA Chic and stylish apartment situated close to the heart of the city. '

# %% [markdown]
# - host_response_time (null imputation)

# %%
listings.loc[6, 'host_response_time']
# Out:
# nan

# %% [markdown]
# - host_response_rate (**impute with mean**)
#     - Idea: it is reasonable to use the mean to predict those hosts who do not have response

# %%
listings['host_response_rate'] = listings['host_response_rate'].fillna(-1)

# %%
listings['host_response_rate'] = listings['host_response_rate'].apply(lambda x : x if x == -1 else float(x[:-1]))

# %%
listings.host_response_rate
# Out:
# 0        100.0
# 1         -1.0
# 2          0.0
# 3         -1.0
# 4         -1.0
#          ...
# 17069    100.0
# 17070      0.0
# 17071     50.0
# 17072     75.0
# 17073     75.0
# Name: host_response_rate, Length: 17020, dtype: float64

# %%
# calculate the mean
np.mean(listings.host_response_rate[listings.host_response_rate != -1])
# Out:
# 81.55574989068649

# %%
listings['host_response_rate'] = listings['host_response_rate'].apply(lambda x: 81 if x == -1 else x)

# %%
listings.host_response_rate.head()
# Out:
# 0    100.0
# 1     81.0
# 2      0.0
# 3     81.0
# 4     81.0
# Name: host_response_rate, dtype: float64

# %% [markdown]
# - host_acceptance_rate (impute with mean)
#     - for the similar reason

# %%
listings['host_acceptance_rate'] = listings['host_acceptance_rate'].fillna(-1)
listings['host_acceptance_rate'] = listings['host_acceptance_rate'].apply(lambda x : x if x == -1 else float(x[:-1]))
listings['host_acceptance_rate']
# Out:
# 0         -1.0
# 1         -1.0
# 2         -1.0
# 3        100.0
# 4         -1.0
#          ...
# 17069    100.0
# 17070     -1.0
# 17071     -1.0
# 17072     90.0
# 17073     90.0
# Name: host_acceptance_rate, Length: 17020, dtype: float64

# %%
np.mean(listings.host_acceptance_rate[listings.host_acceptance_rate != -1])
# Out:
# 85.7900466562986

# %%
listings['host_acceptance_rate'] = listings['host_acceptance_rate'].apply(lambda x: 86 if x == -1 else x)
listings.host_acceptance_rate.head()
# Out:
# 0     86.0
# 1     86.0
# 2     86.0
# 3    100.0
# 4     86.0
# Name: host_acceptance_rate, dtype: float64

# %% [markdown]
# - 'host_neighbourhood', 'neighbourhood', 'bathrooms_text', 'bedrooms', 'beds' (impute with null)
#     - consider whether some attrs are really meaningful

# %%
listings[['host_neighbourhood', 'neighbourhood', 'bathrooms_text', 'bedrooms', 'beds']].head(10)
# Out:
#   host_neighbourhood                                      neighbourhood  \
# 0                NaN  Tambon Talat Kwan, Chang Wat Nonthaburi, Thailand
# 1                NaN                                                NaN
# 2                NaN                Tambon Ban Mai, จ.นนทบุรี, Thailand
# 3                NaN        ตำบล บางพูด, Chang Wat Nonthaburi, Thailand
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6   Victory Monument                      Samsen Nai, Bangkok, Thailand
# 7                NaN                                                NaN
# 8          Bang Kapi                                  Bangkok, Thailand
# 9                NaN                                  Bangkok, Thailand
#
#    bathrooms_text bedrooms beds
# 0          1 bath        1    1
# 1          1 bath        1    1
# 2          1 bath        1    1
# 3  1 private bath        1    1
# 4  2 shared baths        1    1
# 5  3 shared baths        1    2
# 6       1.5 baths        1    1
# 7          1 bath        1    2
# 8          1 bath        1    1
# 9  1 private bath        1    1

# %% [markdown]
# - first_review, last_review (impute with null)

# %%
listings[['id', 'first_review', 'last_review']].head()
# Out:
#                    id first_review last_review
# 0  645048906856594097          NaN         NaN
# 1            15636062          NaN         NaN
# 2            39544047   2019-11-15  2020-03-05
# 3            34002624   2019-06-01  2019-12-07
# 4            22678899          NaN         NaN

# %% [markdown]
# - review_scores_rating， review_scores_accurarcy, ..., review_scores_value (impute with mean)

# %%
reviews_list = list(listings.isnull().sum()[listings.isnull().sum() != 0].index[12:-1])
reviews_list
# Out:
# ['review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value']

# %%
# showcase
listings[['id'] + reviews_list].head()
# Out:
#                    id review_scores_accuracy review_scores_cleanliness  \
# 0  645048906856594097                    NaN                       NaN
# 1            15636062                    NaN                       NaN
# 2            39544047                    5.0                       5.0
# 3            34002624                    5.0                       5.0
# 4            22678899                    NaN                       NaN
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                   NaN                         NaN                    NaN
# 1                   NaN                         NaN                    NaN
# 2                   5.0                         5.0                   4.67
# 3                   5.0                         4.0                    4.5
# 4                   NaN                         NaN                    NaN
#
#   review_scores_value
# 0                 NaN
# 1                 NaN
# 2                4.67
# 3                 4.0
# 4                 NaN

# %%
for attr in reviews_list:
    listings[attr] = listings[attr].astype(float)
    listings[attr] = listings[attr].fillna(np.mean(listings[attr]))

# %%
listings[['id'] + reviews_list].head()
# Out:
#                    id  review_scores_accuracy  review_scores_cleanliness  \
# 0  645048906856594097                4.710614                   4.676348
# 1            15636062                4.710614                   4.676348
# 2            39544047                5.000000                   5.000000
# 3            34002624                5.000000                   5.000000
# 4            22678899                4.710614                   4.676348
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0               4.754167                     4.764909                4.600394
# 1               4.754167                     4.764909                4.600394
# 2               5.000000                     5.000000                4.670000
# 3               5.000000                     4.000000                4.500000
# 4               4.754167                     4.764909                4.600394
#
#    review_scores_value
# 0             4.641145
# 1             4.641145
# 2             4.670000
# 3             4.000000
# 4             4.641145

# %% [markdown]
# - reviews_per_month (impute with null)

# %%
listings[['id', 'reviews_per_month']].head()
# Out:
#                    id reviews_per_month
# 0  645048906856594097               NaN
# 1            15636062               NaN
# 2            39544047              0.19
# 3            34002624              0.08
# 4            22678899               NaN

# %% [markdown]
# ### Appendix: While checking, I find that: (different attribute name)
#     - listings : neighbourhood_cleansed corresponds to
#     - listings_summary: neighbourhood

# %%
listings_summary[['neighbourhood', 'id']][listings_summary.id == '645048906856594097']
# Out:
#   neighbourhood                  id
# 3      Bang Sue  645048906856594097

# %%
listings[['neighbourhood_cleansed', 'id']][listings.id == '645048906856594097']
# Out:
#   neighbourhood_cleansed                  id
# 0               Bang Sue  645048906856594097

# %% [markdown]
# ## Now, the null value is:

# %%
listings.isnull().sum()[listings.isnull().sum() != 0]
# Out:
# description               899
# neighborhood_overview    7581
# host_about               7192
# host_response_time       5585
# host_neighbourhood       7222
# neighbourhood            7581
# bathrooms_text            136
# bedrooms                 1699
# beds                      515
# first_review             7023
# last_review              7023
# review_scores_rating     7023
# reviews_per_month        7023
# dtype: int64

# %% [markdown]
# ## Data after cleaning

# %%
listings
# Out:
#                        id                                      listing_url  \
# 0      645048906856594097  https://www.airbnb.com/rooms/645048906856594097
# 1                15636062            https://www.airbnb.com/rooms/15636062
# 2                39544047            https://www.airbnb.com/rooms/39544047
# 3                34002624            https://www.airbnb.com/rooms/34002624
# 4                22678899            https://www.airbnb.com/rooms/22678899
# ...                   ...                                              ...
# 17069            22947580            https://www.airbnb.com/rooms/22947580
# 17070             5955949             https://www.airbnb.com/rooms/5955949
# 17071            32650300            https://www.airbnb.com/rooms/32650300
# 17072            46851152            https://www.airbnb.com/rooms/46851152
# 17073            46851039            https://www.airbnb.com/rooms/46851039
#
#             scrape_id last_scraped  \
# 0      20220620202126   2022-06-20
# 1      20220620202126   2022-06-20
# 2      20220620202126   2022-06-20
# 3      20220620202126   2022-06-20
# 4      20220620202126   2022-06-20
# ...               ...          ...
# 17069  20220620202126   2022-06-20
# 17070  20220620202126   2022-06-20
# 17071  20220620202126   2022-06-20
# 17072  20220620202126   2022-06-20
# 17073  20220620202126   2022-06-20
#
#                                                     name  \
# 0          Furnished 1 bedroom condo with beautiful view
# 1                               Akesin place ngamwongwan
# 2         IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                              Popular Condo Near IMPACT
# 4                                              บ้านเบนซ์
# ...                                                  ...
# 17069      Apartment T9 Muang Thong Thani by KhunNutt2B7
# 17070  Cozy Manor house with Lake view 520 square meters
# 17071                Studio Superior (Double Bed) Room 1
# 17072      Family Room Dmk Don mueang Airport 2 bedrooms
# 17073               Impact -Challenger Muang thong Thani
#
#                                              description  \
# 0      🏢Condo For rent: Lumpini Ville Nakhon In-River...
# 1      ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...
# 2                                                    NaN
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4      เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...
# ...                                                  ...
# 17069  ห้องพักส่วนตัวสวยหรูอยู่สบาย สะอาด ราคาประหยัด...
# 17070  Nice place for relax with wide lake at opposit...
# 17071  - Room size 25 sq.m. or 322 sq.ft.<br />- Quee...
# 17072  Apartment in Pak Kret, 2 bedrooms, 1 bathroom,...
# 17073  Apartment in Pak Kret, 1 bedroom, 1 bathroom, ...
#
#                                    neighborhood_overview  \
# 0                                Its in Lumpini building
# 1                                                    NaN
# 2      IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4                                                    NaN
# ...                                                  ...
# 17069  ที่พักอยู่ใกล้ห้างคอสโม แหล่งช้อปปิ้ง Sport Fa...
# 17070  There are many Thai restaurant near entrance o...
# 17071  Bangna Tower<br />40,000 square meters project...
# 17072                                                NaN
# 17073                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...    4663219
# 1      https://a0.muscache.com/pictures/f68098b9-3ff2...  100840975
# 2      https://a0.muscache.com/pictures/cc410e7d-922f...  303573998
# 3      https://a0.muscache.com/pictures/e4811699-0153...  256747704
# 4      https://a0.muscache.com/pictures/02e4ae53-dbe6...  167136634
# ...                                                  ...        ...
# 17069  https://a0.muscache.com/pictures/2cbf3a10-76e8...  169985358
# 17070  https://a0.muscache.com/pictures/93a7608f-f35c...   20002101
# 17071  https://a0.muscache.com/pictures/9a88370c-111c...  245251233
# 17072  https://a0.muscache.com/pictures/prohost-api/H...  201741826
# 17073  https://a0.muscache.com/pictures/prohost-api/H...  201741826
#
#                                           host_url  ... review_scores_checkin  \
# 0        https://www.airbnb.com/users/show/4663219  ...              4.754167
# 1      https://www.airbnb.com/users/show/100840975  ...              4.754167
# 2      https://www.airbnb.com/users/show/303573998  ...              5.000000
# 3      https://www.airbnb.com/users/show/256747704  ...              5.000000
# 4      https://www.airbnb.com/users/show/167136634  ...              4.754167
# ...                                            ...  ...                   ...
# 17069  https://www.airbnb.com/users/show/169985358  ...              4.754167
# 17070   https://www.airbnb.com/users/show/20002101  ...              4.754167
# 17071  https://www.airbnb.com/users/show/245251233  ...              4.754167
# 17072  https://www.airbnb.com/users/show/201741826  ...              4.754167
# 17073  https://www.airbnb.com/users/show/201741826  ...              4.754167
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                        4.764909               4.600394            4.641145
# 1                        4.764909               4.600394            4.641145
# 2                        5.000000               4.670000            4.670000
# 3                        4.000000               4.500000            4.000000
# 4                        4.764909               4.600394            4.641145
# ...                           ...                    ...                 ...
# 17069                    4.764909               4.600394            4.641145
# 17070                    4.764909               4.600394            4.641145
# 17071                    4.764909               4.600394            4.641145
# 17072                    4.764909               4.600394            4.641145
# 17073                    4.764909               4.600394            4.641145
#
#       instant_bookable  calculated_host_listings_count  \
# 0                    t                               1
# 1                    f                               1
# 2                    t                               2
# 3                    t                               1
# 4                    t                               1
# ...                ...                             ...
# 17069                t                               1
# 17070                f                               2
# 17071                t                              29
# 17072                t                              48
# 17073                t                              48
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                1
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 17069                                            1
# 17070                                            1
# 17071                                            0
# 17072                                           23
# 17073                                           23
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                1
# 2                                                2
# 3                                                1
# 4                                                1
# ...                                            ...
# 17069                                            0
# 17070                                            1
# 17071                                           29
# 17072                                           18
# 17073                                           18
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0               NaN
# 1                                               0               NaN
# 2                                               0              0.19
# 3                                               0              0.08
# 4                                               0               NaN
# ...                                           ...               ...
# 17069                                           0               NaN
# 17070                                           0               NaN
# 17071                                           0               NaN
# 17072                                           7               NaN
# 17073                                           7               NaN
#
# [17020 rows x 70 columns]
